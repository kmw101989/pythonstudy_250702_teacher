# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com/accounts/login")
print("수동으로 인증 시작!")
time.sleep(30)

with open("instagram_cookies.pkl", "wb") as f :
    pickle.dump(driver.get_cookies(), f)

print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동으로 인증 시작!
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com")

with open("instagram_cookies.pkl", "rb") as f :
    cookies = pickle.load(f)
for cookie in cookies :
    driver.add_cookie(cookie)

driver.refresh()
time.sleep(5)

try :
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)
except :
    pass

keyword = "무신사"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(5)

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try :
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url": url, "caption": caption})
    except Exception as e :
        print(f"캡션 추출 실패 : {url} | 에러 : {e}")
        continue
        
driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DKYzPVDOuhV/
# Photo shared by 금새로키 on June 01, 2025 tagging @musinsa.official, and @originals_kr. 사람 1명, 운동복 하의 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DJ1qpcdSlU_/
# Photo shared by 자몽 on May 19, 2025 tagging @galexofficial_. 반바지, 미니스커트, 그물코 스타킹 및 타이츠의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMNUbqKhrwt/
# Photo shared by 제스트 매거진 on July 17, 2025 tagging @musinsa.official. 사람 1명, 반바지 및 문구: '무신사 긴팔 티셔츠 랭킹 무신사긴팔티셔츠랭킹1위 1위 zest R: 무신사 여성 숏팬츠 무신사여성못괜츠1위 1위 * #요즘트렌드#무신사랭킹 #무신사랭킹 요즘트렌드 올 여름 여름아이템은 무신사 랭킹이 핫해'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLw818YJxkP/
# Photo shared by 오도르부부 on July 06, 2025 tagging @whitewaterboys, @clevercloger, @odor_leather, @humtto_kr, @tarrytown_official, and @cossoc_shop. 사람 2명, 어린이, 야구하는 사람들 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKwMo6vhUOo/
# Photo by 셀패진 on June 11, 2025. 문구: 'celeb Fashion Magazine A BATHING APE R SINCE SINCE1993 1993 베이프, 이제 무신사에서 판다'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DIgHAdGSgLr/
# Photo by 민수픽 on April 16, 2025. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DMdy43aTQnk/
# Photo shared by 이주희 on July 23, 2025 tagging @pimadaziwin.official. 사람 1명, 반바지, 미니스커트 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLyrlpBzx9S/
# Photo shared by 우희성 on July 06, 2025 tagging @allclassic_official. 사람 1명, 윙팁 신발, 담배 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DL7ths5zdBE/
# Photo by @_yeuu.n on July 10, 2025. 사람 1명, 머리카락, 상의, 야외 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DL96UXQpQUR/
# Photo shared by @bella_w.young on July 11, 2025 tagging @musinsa.official, and @nikeseoul. 사람 1명, 샌들, 운동화, 슬링백 신발 및 텍스트의 이미지일 수 있음.
# ============================================================
