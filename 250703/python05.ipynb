# %% [markdown]
# - 구구단을 2단부터 9단까지 다음과 같이 출력해주세요!!! // 사용자에게 값을 받지 않는다!!
#   ```
#   2 x 1 = 2
#   2 x 2 = 4
#   ...
#   2 x 9 = 18
#   3 x 1 = 3
#   3 x 2 = 6
#   ...
#   9 x 9 = 81
#   ```

# %%
for num01 in range(2, 10) :
    print("------------")
    print(f"- 구구단 {num01}단 -")
    print("------------")
    for num02 in range(1, 10) :
        print(f"{num01} x {num01} = {num01*num02}")
    print("------------")
    print()
# Out:
# ------------
# - 구구단 2단 -
# ------------
# 2 x 2 = 2
# 2 x 2 = 4
# 2 x 2 = 6
# 2 x 2 = 8
# 2 x 2 = 10
# 2 x 2 = 12
# 2 x 2 = 14
# 2 x 2 = 16
# 2 x 2 = 18
# ------------
#
# ------------
# - 구구단 3단 -
# ------------
# 3 x 3 = 3
# 3 x 3 = 6
# 3 x 3 = 9
# 3 x 3 = 12
# 3 x 3 = 15
# 3 x 3 = 18
# 3 x 3 = 21
# 3 x 3 = 24
# 3 x 3 = 27
# ------------
#
# ------------
# - 구구단 4단 -
# ------------
# 4 x 4 = 4
# 4 x 4 = 8
# 4 x 4 = 12
# 4 x 4 = 16
# 4 x 4 = 20
# 4 x 4 = 24
# 4 x 4 = 28
# 4 x 4 = 32
# 4 x 4 = 36
# ------------
#
# ------------
# - 구구단 5단 -
# ------------
# 5 x 5 = 5
# 5 x 5 = 10
# 5 x 5 = 15
# 5 x 5 = 20
# 5 x 5 = 25
# 5 x 5 = 30
# 5 x 5 = 35
# 5 x 5 = 40
# 5 x 5 = 45
# ------------
#
# ------------
# - 구구단 6단 -
# ------------
# 6 x 6 = 6
# 6 x 6 = 12
# 6 x 6 = 18
# 6 x 6 = 24
# 6 x 6 = 30
# 6 x 6 = 36
# 6 x 6 = 42
# 6 x 6 = 48
# 6 x 6 = 54
# ------------
#
# ------------
# - 구구단 7단 -
# ------------
# 7 x 7 = 7
# 7 x 7 = 14
# 7 x 7 = 21
# 7 x 7 = 28
# 7 x 7 = 35
# 7 x 7 = 42
# ...
